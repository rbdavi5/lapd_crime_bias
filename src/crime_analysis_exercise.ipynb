# %% [markdown]
# # Big Data IV - Ejercicio de Análisis Básico con Interpretación de Negocio
# ### Dataset: Crime Data (2020 - presente)
#
# Instrucciones:
# - Completa las celdas marcadas con **TODO**.
# - Usa pandas, matplotlib o seaborn.
# - Al final responde las preguntas de negocio basadas en los gráficos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Cargar el dataset (ajusta el nombre del archivo si es diferente)
df = pd.read_csv("crime_data.csv")

# TODO: Mostrar las primeras 5 filas

# %% [markdown]
# ## 1. Exploración inicial

# %%
# TODO: Mostrar información general del dataset
# (columnas, tipos de datos, valores nulos)

# %%
# TODO: Estadísticas descriptivas básicas

# %% [markdown]
# ## 2. Limpieza simple

# %%
# TODO: Contar cuántos valores nulos hay en cada columna

# %%
# TODO: Reemplazar valores nulos en la columna de tipo de crimen por "Desconocido"

# %% [markdown]
# ## 3. Análisis exploratorio

# %%
# TODO: Encontrar los 3 tipos de crímenes más frecuentes

# %%
# TODO: Calcular número de crímenes por año

# %%
# TODO: Identificar el mes con más crímenes en todo el dataset

# %% [markdown]
# ## 4. Visualizaciones básicas

# %%
# TODO: Gráfico de barras con los 5 crímenes más comunes

# %%
# TODO: Gráfico de línea con la evolución de crímenes por año

# %% [markdown]
# ## 5. Análisis adicional con enfoque de negocio

# %%
# TODO: Crear columna 'day_of_week' y graficar número de crímenes por día de la semana
# Sugerencia: usa df['date'].dt.day_name()

# %%
# TODO: Crear heatmap de crímenes por mes y tipo de crimen
# Sugerencia: agrupa con groupby(['month','crime_type']).size().unstack()

# %% [markdown]
# ### Preguntas de negocio:
# 1. ¿Se concentran ciertos crímenes en fines de semana?
# 2. ¿Existen meses con más actividad criminal? ¿Qué delitos destacan en esos meses?
# 3. ¿Hubo cambios notables en la evolución del crimen en 2020 (pandemia)?
# 4. Si fueras parte del Departamento de Policía, ¿qué acciones priorizarías con esta información?

# %% [markdown]
# ## 6. Reflexión

# %%
# Escribe aquí tus conclusiones de negocio basadas en los análisis anteriores.
# Ejemplo: "Los delitos de robo aumentan en diciembre, lo que sugiere reforzar seguridad en temporada navideña."
